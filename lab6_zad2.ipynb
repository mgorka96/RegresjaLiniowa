# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#wczytanie danych z pliku
df=pd.read_csv("/home/michal/AiBD/lab6/beauty.csv")

# %%
#
X = df['btystdave']
Y = df['courseevaluation']
X = sm.add_constant(X)
X
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)
print(model.params)
predictions
# Out:
# const        4.010023
# btystdave    0.133001
# dtype: float64
# 0      4.036831
# 1      3.900153
# 2      3.922197
# 3      3.908102
# 4      4.199077
#          ...
# 458    4.162049
# 459    4.162049
# 460    4.054186
# 461    4.054186
# 462    4.054186
# Length: 463, dtype: float64

# %%
X1 = df['btystdave']
Y1 = model.params[0] + model.params[1] * X1
Y1
# Out:
# 0      4.036831
# 1      3.900153
# 2      3.922197
# 3      3.908102
# 4      4.199077
#          ...
# 458    4.162049
# 459    4.162049
# 460    4.054186
# 461    4.054186
# 462    4.054186
# Name: btystdave, Length: 463, dtype: float64

# %%
df2 = pd.DataFrame(df,columns=['btystdave','courseevaluation'])
df2.values[:,1] = predictions
df2
# Out:
#      btystdave  courseevaluation
# 0     0.201567          4.036831
# 1    -0.826081          3.900153
# 2    -0.660333          3.922197
# 3    -0.766312          3.908102
# 4     1.421445          4.199077
# ..         ...               ...
# 458   1.143045          4.162049
# 459   1.143045          4.162049
# 460   0.332051          4.054186
# 461   0.332051          4.054186
# 462   0.332051          4.054186
#
# [463 rows x 2 columns]

# %%
df2.plot.scatter(x='btystdave',y='courseevaluation',marker='o')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.set(style="whitegrid")

sns.residplot(df['btystdave'], df['courseevaluation'], lowess=True, color="r")
plt.show()

# %%
sns.residplot(df2['btystdave'], df2['courseevaluation'], lowess=True, color="r")
plt.show()

# %%
X2 = df[['btystdave', 'btystdfu', 'btystdmu']]
Y2 = df['courseevaluation']
X2 = sm.add_constant(X)
X2
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)
print(model.params)
predictions
# Out:
# const        4.012468
# btystdave   -0.041680
# btystdfu     0.083174
# btystdmu     0.087593
# dtype: float64
# 0      4.059795
# 1      3.941564
# 2      3.854097
# 3      3.979352
# 4      4.169961
#          ...
# 458    4.141178
# 459    4.141178
# 460    4.175087
# 461    4.175087
# 462    4.175087
# Length: 463, dtype: float64

# %%
df3 = pd.DataFrame(df,columns=['btystdave', 'btystdfu', 'btystdmu', 'courseevaluation'])
df3.values[:,3] = predictions
df3
# Out:
#      btystdave  btystdfu  btystdmu  courseevaluation
# 0     0.201567  0.875814 -0.195418          4.059795
# 1    -0.826081 -0.577006 -0.654651          3.941564
# 2    -0.660333 -1.545553 -0.654651          3.854097
# 3    -0.766312 -0.092733 -0.654651          3.979352
# 4     1.421445  1.844361  0.723047          4.169961
# ..         ...       ...       ...               ...
# 458   1.143045  0.391540  1.641512          4.141178
# 459   1.143045  0.391540  1.641512          4.141178
# 460   0.332051  1.360087  0.723047          4.175087
# 461   0.332051  1.360087  0.723047          4.175087
# 462   0.332051  1.360087  0.723047          4.175087
#
# [463 rows x 4 columns]

# %%
df3.plot.scatter(x='btystdave',y='courseevaluation',marker='o')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.residplot(df3['btystdave'], df3['courseevaluation'], lowess=True, color="r")
plt.show()

# %%
df3.plot.scatter(x='btystdfu',y='courseevaluation',marker='o')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.residplot(df3['btystdfu'], df3['courseevaluation'], lowess=True, color="r")
plt.show()

# %%
df3.plot.scatter(x='btystdmu',y='courseevaluation',marker='o')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.residplot(df3['btystdmu'], df3['courseevaluation'], lowess=True, color="r")
plt.show()
